# %%
from MOF_builder.tetratopic import MOF_tetra
import numpy as np
import veloxchem as vlx
from frag_recognizer import process_linker_molecule


template = 'csq.cif' #lib file 'she.cif' 6 
node_connection= 8   #lib file 
linker_topic = 4
linker_file = 'CoTCPP.xyz'

#######################################################################
! rm nodes/.DS_Store
! rm nodes/*tetra*.cif
! rm edges/.DS_Store
! rm edges/*.cif
molecule = vlx.Molecule.read_xyz_file(linker_file)
process_linker_molecule(molecule,linker_topic)

templates_dir = '../data/template_database' #default 
nodes_dir = 'nodes' #default 
edges_dir = 'edges' #default 
new_mof = MOF_tetra(templates_dir,nodes_dir,edges_dir,template,node_connection)
new_mof.load(False)
# Out:
# rm: cannot remove 'nodes/.DS_Store': No such file or directory
# rm: cannot remove 'edges/.DS_Store': No such file or directory
# center is a cycle
# [0, 1, 20, 6, 5, 7, 23, 11, 10, 12, 22, 17, 15, 16, 21, 2]
# tritopic/tetratopic/multitopic: center is a cycle
# find connected X in edge frag 33 30 20
# find connected X in edge frag 39 36 23
# find connected X in edge frag 45 42 22
# find connected X in edge frag 27 24 21
# center_frag: 32 [20, 21, 22, 23]
# outer_frag: 10 [0, 3]
#
# =========================================================================================================
# template : csq.cif
# =========================================================================================================
#
# Number of vertices =  9
# Number of edges =  24
#
# *****************************************************************
# RMSD of the compatible node BBs with assigned vertices:
# *****************************************************************
#
# vertex Er (8 connected)
#      8c_Zr_1_Ch.cif deviation = 0.08414 (within tolerance)
# * 1 compatible building blocks out of 1 available for node Er *
# vertex V (4 connected)
#      tetracenter.cif deviation = 0.1697 (within tolerance)
# * 1 compatible building blocks out of 1 available for node V *
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# vertex assignment :  ['v1-tetracenter.cif', 'v2-8c_Zr_1_Ch.cif']
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# edge assignment :  ('tetraedge.cif',)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# scaling unit cell and vertex positions...
# optimizing with local minimization algorithm L-BFGS-B...
#
# The final objective function value is 116354.971
#
# *******************************************
# The scaled unit cell parameters are :
# *******************************************
# a    : 43.32445
# b    : 43.32965
# c    : 16.00252
# alpha: 89.99866
# beta : 89.99762
# gamma: 120.00801
# <class 'networkx.utils.decorators.argmap'> compilation 80:3: FutureWarning:
#
# shortest_path will return an iterator that yields
# (node, path) pairs instead of a dictionary when source
# and target are unspecified beginning in version 3.5
#
# To keep the current behavior, use:
#
# 	dict(nx.shortest_path(G))

# %%
#from output import temp_xyz
#temp_xyz('40test.xyz',new_mof.all_connected_node_edge_cc[new_mof.all_connected_node_edge_cc[:,5]==1])

# %%
supercell= np.asarray([0,0,0])
new_mof.basic_supercell(supercell,term_file = '../data/terminations_database/methyl.pdb')
new_mof.write_basic_supercell('41.gro','42.xyz')
# Out:
# row_diff_idx_loose [3, 4, 5, 9, 10, 11, 19, 20, 21, 22, 26, 27, 28, 36, 39, 40, 42, 45, 46, 48, 51, 53, 54, 57, 58, 124, 125, 126, 130, 131, 132, 137, 140, 142, 147, 148, 149, 153, 154, 155, 162, 165, 167, 168, 171, 173, 174, 176, 179, 180, 184, 188, 190, 196, 198, 200, 201, 202, 203, 204, 205, 207, 208, 211, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258,
1NOD    O43   43   3.447   1.745   0.783\n    1NOD    O44   44   3.041   1.958   0.771\n    1NOD    O45   45   3.235   1.622   0.771\n    1NOD    O46   46   3.253   2.081   0.783\n    1NOD    H47   47   3.388   1.935   1.073\n    1NOD    H48   48   2.942   2.008   0.768\n    1NOD    H49   49   3.412   1.949   0.499\n    1NOD    H50   50   3.229   1.512   0.768\n    1NOD    H51   51   2.972   2.178   0.906\n    1NOD    H52   52   3.108   2.246   0.679\n    1NOD    H53   53   3.157   1.916   0.365\n    1NOD    H54   54   3.366   1.794   0.362\n    1NOD    H55   55   3.516   1.537   0.682\n    1NOD    H56   56   3.398   1.458   0.885\n    1NOD    H57   57   3.210   1.723   1.179\n    1NOD    H58   58   3.216   1.965   1.198\n    1NOD    H59   59   3.388   1.639   0.366\n    1NOD    H60   60   3.441   1.490   1.031\n    1NOD    H61   61   3.097   2.065   1.188\n    1NOD    H62   62   3.046   2.218   0.538\n    2NOD     O1   63   1.129   1.540   0.582\n    2NOD     O2   64   1.334   1.580   0.729\n    2NOD     C3   65   1.265   1.518   0.621\n    2NOD     O4   66   1.067   2.151   0.565\n    2NOD     O5   67   0.851   2.118   0.696\n    2NOD     C6   68   0.929   2.174   0.591\n    2NOD     O7   69   1.378   1.971   0.582\n    2NOD     O8   70   1.446   1.774   0.729\n    2NOD     C9   71   1.465   1.865   0.621\n    2NOD    O10   72   0.818   1.720   0.565\n    2NOD    O11   73   0.739   1.923   0.696\n    2NOD    C12   74   0.729   1.828   0.591\n    2NOD   Zr13   75   1.011   1.703   0.657\n    2NOD    O14   76   1.027   1.710   0.447\n    2NOD    O15   77   0.890   1.528   0.661\n    2NOD   Zr16   78   1.178   1.992   0.657\n    2NOD    O17   79   1.203   1.977   0.446\n    2NOD    O18   80   1.263   2.186   0.673\n    2NOD    O19   81   1.201   1.786   0.636\n    2NOD    O20   82   0.991   1.908   0.624\n    2NOD    O21   83   0.797   1.732   1.064\n    2NOD    O22   84   0.729   1.929   0.917\n    2NOD    C23   85   0.711   1.838   1.025\n    2NOD    O24 ...

# %%
new_mof.defect_missing([1,2,3],[1,2,3])
new_mof.term_defective_model(n_term_file = '../data/methyl.pdb',e_termfile = '../data/CCO2H2.pdb')
new_mof.write_tntemof('45.gro')
# Out:
# this MOF has 5 seperated fragments: [6, 1, 1, 1, 1]
# UNsaturated edges(linkers) exist, need linker_termination <= 8
# UNsaturated nodes exist, <=2 nodes need node_termination
# /Users/chenxili/miniconda/envs/vlx/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/chenxili/miniconda/envs/vlx/lib/python3.11/site-packages/numpy/core/_methods.py:131: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret / rcount
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 new_mof.defect_missing([1,2,3],[1,2,3])
# ----> 2 new_mof.term_defective_model(n_term_file = '../data/methyl.pdb',e_termfile = '../data/CCO2H2.pdb')
#       3 new_mof.write_tntemof('45.gro')
#
# File ~/GitHub/MOFbuilder/tests/MOF_builder/tetratopic.py:534, in MOF_tetra.term_defective_model(self, n_term_file, e_termfile)
#     532 #add -methyl to terminate nodes find exposed xoo
#     533 ex_node_cxo_cc_loose=exposed_xoo_cc(eG,unsaturated_main_frag_nodes,main_frag_nodes_cc,con_nodes_x_dict,xoo_dict)
# --> 534 n_terms_loose = add_node_terminations(n_term_file,ex_node_cxo_cc_loose)
#     535 n_terms_cc = np.vstack((n_terms_loose))
#     536 self.n_terms_cc = n_terms_cc
#
# File ~/GitHub/MOFbuilder/tests/MOF_builder/functions/terminations.py:132, in add_node_terminations(term_file, ex_node_cxo_cc)
#     129 terms_append = terms.append
#     130 node_oovecs_record_append = node_oovecs_record.append
# --> 132 term_data=termpdb(term_file)
#     133 term_info = term_data[:,:-3]
#     134 term_coords = term_data[:,-3:]
#
# File ~/GitHub/MOFbuilder/tests/MOF_builder/functions/terminations.py:10, in termpdb(filename)
#       8 def termpdb(filename):
#       9         inputfile = str(filename)
# ---> 10         with open(inputfile, "r") as fp:
#      11             content = fp.readlines()
#      12             #linesnumber = len(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/methyl.pdb'

# %%
#SUB
sub_file = 'TETRA_SUB.pdb'
sub_class = 'HEDGE' #HHEDGE HHHEDGE EDGE
candidate_res_idx_list = [6,7,8,9,14,18] #10,13
sub_res_newname = 'SUB'
new_mof.defect_replace_linker(sub_file,sub_class,candidate_res_idx_list)
new_mof.write_view_replaced('46.gro')
# Out:
# <div id="3dmolviewer_17313125565745778"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17313125565745778" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17313125565745778 = null;
# var warn = document.getElementById("3dmolwarning_17313125565745778");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17313125565745778 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17313125565745778"),{backgroundColor:"white"});
# viewer_17313125565745778.zoomTo();
# 	viewer_17313125565745778.addModelsAsFrames("generated by MOF_BUILD\n4103\n    4NOD    D70    1  -0.323   1.518   1.680\n    4NOD    D71    2  -0.284   1.580   1.854\n    4NOD    D68    3  -0.367   1.502   1.796\n    4NOD    D73    4  -0.188   1.562   1.804\n    4NOD    D74    5  -0.230   1.599   1.709\n    4NOD    Zr1    6  -0.276   1.531   1.767\n    4NOD    D72    7  -0.327   1.617   1.759\n    4NOD    D69    8  -0.255   1.458   1.832\n    4NOD    D67    9  -0.234   1.458   1.713\n    4NOD    D82   10  -0.122   1.943   1.796\n    4NOD    D76   11  -0.175   2.069   1.930\n    4NOD    D80   12  -0.176   1.924   1.941\n    4NOD    D77   13  -0.151   2.065   1.818\n    4NOD    D79   14  -0.219   1.961   1.846\n    4NOD    D81   15  -0.080   1.906   1.891\n    4NOD   Zr13   16  -0.131   1.992   1.883\n    4NOD    D75   17  -0.040   2.021   1.854\n    4NOD    D78   18  -0.083   2.005   1.970\n    4NOD    D83   19  -0.116   1.580   2.058\n    4NOD   Zr14   20  -0.108   1.678   2.038\n    4NOD    D90   21  -0.068   1.741   1.972\n    4NOD    D85   22  -0.100   1.639   1.946\n    4NOD    D84   23  -0.196   1.657   1.997\n    4NOD    D89   24  -0.164   1.759   2.022\n    4NOD    D86   25  -0.014   1.648   2.057\