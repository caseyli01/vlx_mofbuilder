# %%
from MOF_builder.ditopic import MOF_ditopic
from frag_recognizer import process_linker_molecule
import numpy as np
import veloxchem as vlx

template = 'fcu.cif' #UIO6x #lib file 
node_connection= 12   #lib file 
linker_topic = 2
linker_file = 'diC2ph.xyz'
molecule = vlx.Molecule.read_xyz_file('diph.xyz')


#######################################################################
! rm nodes/.DS_Store
! rm edges/.DS_Store
! rm edges/*.cif
process_linker_molecule(molecule,linker_topic)
templates_dir = '../data/template_database' #default 
nodes_dir = 'nodes' #default 
edges_dir = 'edges' #default 
if linker_topic == 2:
    new_mof = MOF_ditopic(templates_dir,nodes_dir,edges_dir,template,node_connection)
    new_mof.load(False)
# Out:
# rm: cannot remove 'nodes/.DS_Store': No such file or directory
# center is two points
# [0, 9]
# ditopic linker: center are two points
# find connected X in edge:   3
# find connected X in edge:   6
# edges/diedge.cif is writen
# center_frag: 20 [3, 6]
#
# =========================================================================================================
# template : fcu.cif
# =========================================================================================================
#
# ['6c_Al_1.cif', '6c_Al_1_Ch_dummy.cif', '6c_Al_mil53 copy.cif', '6c_Al_1_Ch_dummy_dict']
# Number of vertices =  4
# Number of edges =  24
#
# *****************************************************************
# RMSD of the compatible node BBs with assigned vertices:
# *****************************************************************
#
# vertex V (12 connected)
#
# s == v &o==e V1 V1 V2 V2
# s == v &o==e V1 V1 V2 V2
# s == v &o==e V1 V1 V2 V2
# s == v &o==e V1 V1 V2 V2
# s == v &o==e V1 V1 V3 V3
# s == v &o==e V1 V1 V3 V3
# s == v &o==e V1 V1 V3 V3
# s == v &o==e V1 V1 V3 V3
# s == v &o==e V1 V1 V4 V4
# s == v &o==e V1 V1 V4 V4
# s == v &o==e V1 V1 V4 V4
# s == v &o==e V1 V1 V4 V4
# s == v&o==s V1 V2 V1 V2
# s == v&o==s V1 V2 V1 V2
# s == v&o==s V1 V2 V1 V2
# s == v&o==s V1 V2 V1 V2
# s == v &o==e V2 V2 V4 V4
# s == v &o==e V2 V2 V4 V4
# s == v &o==e V2 V2 V4 V4
# s == v &o==e V2 V2 V4 V4
# s == v &o==e V2 V2 V3 V3
# s == v &o==e V2 V2 V3 V3
# s == v &o==e V2 V2 V3 V3
# s == v &o==e V2 V2 V3 V3
# s == v&o==s V1 V3 V1 V3
# s == v&o==s V1 V3 V1 V3
# s == v&o==s V1 V3 V1 V3
# s == v&o==s V1 V3 V1 V3
# s == v&o==s V2 V3 V2 V3
# s == v&o==s V2 V3 V2 V3
# s == v&o==s V2 V3 V2 V3
# s == v&o==s V2 V3 V2 V3
# s == v &o==e V3 V3 V4 V4
# s == v &o==e V3 V3 V4 V4
# s == v &o==e V3 V3 V4 V4
# s == v &o==e V3 V3 V4 V4
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 23
#      21 if linker_topic == 2:
#      22     new_mof = MOF_ditopic(templates_dir,nodes_dir,edges_dir,template,node_connection)
# ---> 23     new_mof.load(False)
#
# File ~/GitHub/MOFbuilder/tests/MOF_builder/ditopic.py:422, in MOF_ditopic.load(self, WRITE_CIF)
#     419 		os.remove(cif)
#     421 self.TG = TG
# --> 422 self.placed_all = placed_all
#     423 self.sc_unit_cell = sc_unit_cell
#     424 self.placed_nodes = placed_nodes
#
# UnboundLocalError: cannot access local variable 'placed_all' where it is not associated with a value

# %%
supercell= np.asarray([0,0,0])
new_mof.basic_supercell(supercell,term_file = '../data/methyl.pdb')
new_mof.write_basic_supercell('21.gro','22.xyz')
new_mof.defect_missing()
new_mof.term_defective_model(n_term_file = '../data/methyl.pdb',e_termfile = '../data/CCO2H2.pdb')
new_mof.write_tntemof('23.gro')
# Out:
# <div id="3dmolviewer_1731035020076715"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1731035020076715" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_1731035020076715 = null;
# var warn = document.getElementById("3dmolwarning_1731035020076715");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1731035020076715 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1731035020076715"),{backgroundColor:"white"});
# viewer_1731035020076715.zoomTo();
# 	viewer_1731035020076715.addModelsAsFrames("generated by MOF_BUILD\n74\n    1NOD     O1    1   0.000   0.353   0.197\n    1NOD     O2    2  -0.000  -0.353   0.197\n    1NOD     O3    3  -0.197  -0.000   0.353\n    1NOD     O4    4   0.197  -0.000   0.353\n    1NOD     O5    5   0.353   0.000   0.197\n    1NOD     O6    6  -0.353  -0.000   0.197\n    1NOD     O7    7  -0.000  -0.197   0.353\n    1NOD     O8    8   0.000   0.197   0.353\n    1NOD    Zr9    9   0.000  -0.000   0.248\n    1NOD    O10   10   0.116  -0.116   0.116\n    1NOD    O11   11  -0.116   0.116   0.116\n    1NOD    C12   12   0.000   0.318   0.318\n    1NOD    C13   13  -0.000  -0.318   0.318\n    1NOD    C14   14  -0.318  -0.000   0.318\n    1NOD    C15   15   0.318  -0.000   0.318\n    1NOD    H16   16  -0.186  -0.186   0.186\n    1NOD    O17   17  -0.116  -0.116   0.116\n    1NOD    H18   18   0.186   0.186   0.186\n    1NOD    O19   19   0.116   0.116   0.116\n    1NOD    O20   20  -0.000  -0.353  -0.197\n    1NOD    O21   21   0.000   0.353  -0.197\n    1NOD    O22   22  -0.353  -0.197  -0.000\n    1NOD    O23   23   0.353  -0.197  -0.000\n    1NOD    O24   24   0.353   0.197   0.000\n    1NOD    O25   25  -0.353   0.197   0.000\n    1NOD    O26   26  -0.197   0.000  -0.353\n    1NOD    O27   27   0.197   0.000  -0.353\n    1NOD    O28   28  -0.353  -0.000  -0.197\n    1NOD    O29   29   0.353   0.000  -0.197\n    1NOD    O30   30  -0.197  -0.353  -0.000\n    1NOD    O31   31  -0.197   0.353   0.000\n    1NOD    O32   32   0.197   0.353   0.000\n    1NOD    O33   33   0.197  -0.353  -0.000\n    1NOD    O34   34  -0.000  -0.197  -0.353\n    1NOD    O35   35   0.000   0.197  -0.353\n    1NOD   Zr36   36  -0.000  -0.248  -0.000\n    1NOD   Zr37   37   0.000   0.248   0.000\n    1NOD   Zr38   38  -0.248  -0.000  -0.000\n    1NOD   Zr39   39   0.248   0.000   0.000\n    1NOD   Zr40   40  -0.000   0.000  -0.248\n    1NOD    O41   41   0.116   0.116  -0.116\n    1NOD    O42   42  -0.116  -0.116  -0.116\n    1NOD    C43   43  -0.000  -0.318  -0.318\n    1NOD    C44   44   0.000   0.318  -0.318\n    1NOD    C45   45  -0.318  -0.318  -0.000\n    1NOD    C46   46   0.318  -0.318  -0.000\n    1NOD
# degree of edge E1 is 1, neighbor nodes are [3]
# degree of edge E4 is 1, neighbor nodes are [3]
# degree of edge E5 is 1, neighbor nodes are [2]
# degree of edge E6 is 1, neighbor nodes are [2]
# degree of edge E9 is 1, neighbor nodes are [2]
# degree of edge E12 is 1, neighbor nodes are [2]
# degree of edge E13 is 1, neighbor nodes are [1]
# degree of edge E14 is 1, neighbor nodes are [1]
# degree of edge E15 is 1, neighbor nodes are [1]
# degree of edge E17 is 1, neighbor nodes are [1]
# degree of edge E18 is 1, neighbor nodes are [1]
# degree of edge E20 is 1, neighbor nodes are [1]
# degree of edge E21 is 1, neighbor nodes are [1]
# degree of edge E22 is 1, neighbor nodes are [1]
# degree of edge E23 is 1, neighbor nodes are [1]
# 1 4
# 4 4
# 5 4
# 6 4
# 9 4
# 12 4
# 13 4
# 14 4
# 15 4
# 17 4
# 18 4
# 20 4
# 21 4
# 22 4
# 23 4
# /Users/chenxili/GitHub/MOFbuilder/tests/MOF_builder/functions/adjust_edges.py:277: RuntimeWarning: invalid value encountered in arccos
#   rad = np.arccos(cos_theta)
# <div id="3dmolviewer_1731035020249823"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1731035020249823" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_1731035020249823 = null;
# var warn = document.getElementById("3dmolwarning_1731035020249823");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1731035020249823 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1731035020249823"),{backgroundColor:"white"});
# viewer_1731035020249823.zoomTo();
# 	viewer_1731035020249823.addModelsAsFrames("generated by MOF_BUILD\n2076\n    1NOD    Zr9    1   0.000  -0.000   0.248\n    1NOD    O10    2   0.116  -0.116   0.116\n    1NOD    O11    3  -0.116   0.116   0.116\n    1NOD    H16    4  -0.186  -0.186   0.186\n    1NOD    O17    5  -0.116  -0.116   0.116\n    1NOD    H18    6   0.186   0.186   0.186\n    1NOD    O19    7   0.116   0.116   0.116\n    1NOD   Zr36    8  -0.000  -0.248  -0.000\n    1NOD   Zr37    9   0.000   0.248   0.000\n    1NOD   Zr38   10  -0.248  -0.000  -0.000\n    1NOD   Zr39   11   0.248   0.000   0.000\n    1NOD   Zr40   12  -0.000   0.000  -0.248\n    1NOD    O41   13   0.116   0.116  -0.116\n    1NOD    O42   14  -0.116  -0.116  -0.116\n    1NOD    H51   15  -0.186   0.186  -0.186\n    1NOD    O52   16  -0.116   0.116  -0.116\n    1NOD    H53   17   0.186  -0.186  -0.186\n    1NOD    O54   18   0.116  -0.116  -0.116\n    2NOD    Zr9   19   0.000   1.353   1.105\n    2NOD    O10   20   0.116   1.469   1.237\n    2NOD    O11   21  -0.116   1.237   1.237\n    2NOD    H16   22  -0.186   1.539   1.167\n    2NOD    O17   23  -0.116   1.469   1.237\n    2NOD    H18   24   0.186   1.167   1.167\n    2NOD    O19   25   0.116   1.237   1.237\n    2NOD   Zr36   26   0.000   1.601   1.353\n    2NOD   Zr37   27   0.000   1.105   1.353\n    2NOD   Zr38   28  -0.248   1.353   1.353\n    2NOD   Zr39   29   0.248   1.353   1.353\n    2NOD   Zr40   30   0.000   1.353   1.601\n    2NOD    O41   31   0.116   1.237   1.469\n    2NOD    O42   32  -0.116   1.469   1.469\n    2NOD    H51   33  -0.186   1.167   1.539\n    2NOD    O52   34  -0.116   1.237   1.469\n    2NOD    H53   35   0.186   1.539   1.539\n    2NOD    O54   36   0.116   1.469   1.469\n    3NOD    Zr9   37   1.601   2.706   1.353\n    3NOD    O10   38   1.469   2.590   1.469\n    3NOD    O11   39   1.469   2.822   1.237\n    3NOD    H16   40   1.539   2.892   1.539\n    3NOD    O17   41   1.469   2.822   1.469\n    3NOD    H18   42   1.539   2.519   1.167\n    3NOD    O19   43   1.469   2.590   1.237\n    3NOD   Zr36   44   1.353   2.706   1.601\n    3NOD   Zr37   45   1.353   2.706   1.105\n    3NOD   Zr38   46   1.353   2.954   1.353\n    3NOD   Zr39   47   1.353   2.457   1.353\n    3NOD   Zr40   48   1.105   2.706   1.353\n    3NOD    O41   49   1.237   2.590   1.237\n    3NOD    O42   50   1.237   2.822   1.469\n    3NOD    H51   51   1.167   2.892   1.167\n    3NOD    O52   52   1.237   2.822   1.237\n    3NOD    H53   53   1.167   2.519   1.539\n    3NOD    O54   54   1.237   2.590   1.469\n    4NOD    Zr9   55   1.105   1.353   2.706\n    4NOD    O10   56   1.237   1.469   2.590\n    4NOD    O11   57   1.237   1.237   2.822\n    4NOD    H16   58   1.167   1.539   2.892\n    4NOD    O17   59   1.237   1.469   2.822\n    4NOD    H18   60   1.167   1.167   2.519\n    4NOD    O19   61   1.237   1.237   2.590\n    4NOD   Zr36   62   1.353   1.601   2.706\n    4NOD   Zr37   63   1.353   1.105   2.706\n    4NOD   Zr38   64   1.353   1.353   2.954\n    4NOD   Zr39   65   1.353   1.353   2.457\n    4NOD   Zr40   66   1.601   1.353   2.706\n    4NOD    O41   67   1.469   1.237   2.590\n    4NOD    O42   68   1.469   1.469   2.822\n    4NOD    H51   69   1.539   1.167   2.892\n    4NOD    O52   70   1.469   1.237   2.822\n    4NOD    H53   71   1.539   1.539   2.519\n    4NOD    O54   72   1.469   1.469   2.590\n    5NOD    Zr9   73   0.000  -0.000   2.954\n    5NOD    O10   74   0.116  -0.116   2.822\n    5NOD    O11   75  -0.116   0.116   2.822\n    5NOD    H16   76  -0.186  -0.186   2.892\n    5NOD    O17   77  -0.116  -0.116   2.822\n    5NOD    H18   78   0.186   0.186   2.892\n    5NOD    O19   79   0.116   0.116   2.822\n    5NOD   Zr36   80  -0.000  -0.248   2.706\n    5NOD   Zr37   81   0.000   0.248   2.706\n    5NOD   Zr38   82  -0.248  -0.000   2.706\n    5NOD   Zr39   83   0.248   0.000   2.706\n    5NOD   Zr40   84  -0.000   0.000   2.457\n    5NOD    O41   85   0.116   0.116   2.590\n    5NOD    O42  ...

# %%
#scalar parameter to adjust boundary 
new_mof.basic_supercell(supercell,scalar=0,boundary_scalar=-0,term_file = '../data/methyl.pdb')
new_mof.write_basic_supercell('24.gro','25.xyz')
# Out:
# <div id="3dmolviewer_17310350204967349"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17310350204967349" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17310350204967349 = null;
# var warn = document.getElementById("3dmolwarning_17310350204967349");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17310350204967349 = $3Dmol.createViewer(document.getElementById("3dmolviewer_
0.116  -0.116  -0.116\n    1NOD    C43   43  -0.000  -0.318  -0.318\n    1NOD    C44   44   0.000   0.318  -0.318\n    1NOD    C45   45  -0.318  -0.318  -0.000\n    1NOD    C46   46   0.318  -0.318  -0.000\n    1NOD    C47   47   0.318   0.318   0.000\n    1NOD    C48   48  -0.318   0.318   0.000\n    1NOD    C49   49  -0.318   0.000  -0.318\n    1NOD    C50   50   0.318   0.000  -0.318\n    1NOD    H51   51  -0.186   0.186  -0.186\n    1NOD    O52   52  -0.116   0.116  -0.116\n    1NOD    H53   53   0.186  -0.186  -0.186\n    1NOD    O54   54   0.116  -0.116  -0.116\n    2NOD     O1   55   0.000   1.000   1.156\n    2NOD     O2   56   0.000   1.706   1.156\n    2NOD     O3   57  -0.197   1.353   1.000\n    2NOD     O4   58   0.197   1.353   1.000\n    2NOD     O5   59   0.353   1.353   1.156\n    2NOD     O6   60  -0.353   1.353   1.156\n    2NOD     O7   61   0.000   1.550   1.000\n    2NOD     O8   62   0.000   1.156   1.000\n    2NOD    Zr9   63   0.000   1.353   1.105\n    2NOD    O10   64   0.116   1.469   1.237\n    2NOD    O11   65  -0.116   1.237   1.237\n    2NOD    C12   66   0.000   1.035   1.035\n    2NOD    C13   67   0.000   1.671   1.035\n    2NOD    C14   68  -0.318   1.353   1.035\n    2NOD    C15   69   0.318   1.353   1.035\n    2NOD    H16   70  -0.186   1.539   1.167\n    2NOD    O17   71  -0.116   1.469   1.237\n    2NOD    H18   72   0.186   1.167   1.167\n    2NOD    O19   73   0.116   1.237   1.237\n    2NOD    O20   74   0.000   1.706   1.550\n    2NOD    O21   75   0.000   1.000   1.550\n    2NOD    O22   76  -0.353   1.550   1.353\n    2NOD    O23   77   0.353   1.550   1.353\n    2NOD    O24   78   0.353   1.156   1.353\n    2NOD    O25   79  -0.353   1.156   1.353\n    2NOD    O26   80  -0.197   1.353   1.706\n    2NOD    O27   81   0.197   1.353   1.706\n    2NOD    O28   82  -0.353   1.353   1.550\n    2NOD    O29   83   0.353   1.353   1.550\n    2NOD    O30   84  -0.197   1.706   1.353\n    2NOD    O31   85  -0.197   1.000   1.353\n    2NOD    O32 ...

# %%
new_mof.unsaturated_main_frag_edges#,new_mof.unsaturated_main_frag_nodes
# Out:
# [('E1', 1),
#  ('E4', 1),
#  ('E5', 1),
#  ('E6', 1),
#  ('E9', 1),
#  ('E12', 1),
#  ('E13', 1),
#  ('E14', 1),
#  ('E15', 1),
#  ('E17', 1),
#  ('E18', 1),
#  ('E20', 1),
#  ('E21', 1),
#  ('E22', 1),
#  ('E23', 1)]

# %%
new_mof.defect_missing([],[1,4,5,6,9,12,13,14,15,17,18,20,21,22,23]) #1,4,5,6,9,12,13,14,15,17,18,20,21,22,23
new_mof.term_defective_model(n_term_file = '../data/methyl.pdb',e_termfile = '../data/CCO2H2.pdb')
new_mof.write_tntemof('26.gro')
# Out:
# this MOF has 1 fragment
# only saturated edges(linkers) exist
# UNsaturated nodes exist, <=14 nodes need node_termination
# <div id="3dmolviewer_1731035020660405"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1731035020660405" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_1731035020660405 = null;
# var warn = document.getElementById("3dmolwarning_1731035020660405");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1731035020660405 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1731035020660405"),{backgroundColor:"white"});
# viewer_1731035020660405.zoomTo();
# 	viewer_1731035020660405.addModelsAsFrames("generated by MOF_BUILD\n1776\n    1NOD    Zr9    1   0.000  -0.000   0.248\n    1NOD    O10    2   0.116  -0.116   0.116\n    1NOD    O11    3  -0.116   0.116   0.116\n    1NOD    H16    4  -0.186  -0.186   0.186\n    1NOD    O17    5  -0.116  -0.116   0.116\n    1NOD    H18    6   0.186   0.186   0.186\n    1NOD    O19    7   0.116   0.116   0.116\n    1NOD   Zr36    8  -0.000  -0.248  -0.000\n    1NOD   Zr37    9   0.000   0.248   0.000\n    1NOD   Zr38   10  -0.248  -0.000  -0.000\n    1NOD   Zr39   11   0.248   0.000   0.000\n    1NOD   Zr40   12  -0.000   0.000  -0.248\n    1NOD    O41   13   0.116   0.116  -0.116\n    1NOD    O42   14  -0.116  -0.116  -0.116\n    1NOD    H51   15  -0.186   0.186  -0.186\n    1NOD    O52   16  -0.116   0.116  -0.116\n    1NOD    H53   17   0.186  -0.186  -0.186\n    1NOD    O54   18   0.116  -0.116  -0.116\n    2NOD    Zr9   19   0.000   1.353   1.105\n    2NOD    O10   20   0.116   1.469   1.237\n    2NOD    O11   21  -0.116   1.237   1.237\n    2NOD    H16   22  -0.186   1.539   1.167\n    2NOD    O17   23  -0.116   1.469   1.237\n    2NOD    H18   24   0.186   1.167   1.167\n    2NOD    O19   25   0.116   1.237   1.237\n    2NOD   Zr36   26   0.000   1.601   1.353\n    2NOD   Zr37   27   0.000   1.105   1.353\n    2NOD   Zr38   28  -0.248   1.353   1.353\n    2NOD   Zr39   29   0.248   1.353   1.353\n    2NOD   Zr40   30   0.000   1.353   1.601\n    2NOD    O41   31   0.116   1.237   1.469\n    2NOD    O42   32  -0.116   1.469   1.469\n    2NOD    H51   33  -0.186   1.167   1.539\n    2NOD    O52   34  -0.116   1.237   1.469\n    2NOD    H53   35   0.186   1.539   1.539\n    2NOD    O54   36   0.116   1.469   1.469\n    3NOD    Zr9   37   1.601   2.706   1.353\n    3NOD    O10   38   1.469   2.590   1.469\n    3NOD    O11   39   1.469   2.822   1.237\n    3NOD    H16   40   1.539   2.892   1.539\n    3NOD    O17   41   1.469   2.822   1.469\n    3NOD    H18   42   1.539   2.519   1.167\n    3NOD    O19   43   1.469   2.590   1.237\n    3NOD   Zr36   44   1.353   2.706   1.601\n    3NOD   Zr37   45   1.353   2.706   1.105\n    3NOD   Zr38   46   1.353   2.954   1.353\n    3NOD   Zr39   47   1.353   2.457   1.353\n    3NOD   Zr40   48   1.105   2.706   1.353\n    3NOD    O41   49   1.237   2.590   1.237\n    3NOD    O42   50   1.237   2.822   1.469\n    3NOD    H51   51   1.167   2.892   1.167\n    3NOD    O52   52   1.237   2.822   1.237\n    3NOD    H53   53   1.167   2.519   1.539\n    3NOD    O54   54   1.237   2.590   1.469\n    4NOD    Zr9   55   1.105   1.353   2.706\n    4NOD    O10   56   1.237   1.469   2.590\n    4NOD    O11   57   1.237   1.237   2.822\n    4NOD    H16   58   1.167   1.539   2.892\n    4NOD    O17   59   1.237   1.469   2.822\n    4NOD    H18   60   1.167   1.167   2.519\n    4NOD    O19   61   1.237   1.237   2.590\n    4NOD   Zr36   62   1.353   1.601   2.706\n    4NOD   Zr37   63   1.353   1.105   2.706\n    4NOD   Zr38   64   1.353   1.353   2.954\n    4NOD   Zr39   65   1.353   1.353   2.457\n    4NOD   Zr40   66   1.601   1.353   2.706\n    4NOD    O41   67   1.469   1.237   2.590\n    4NOD    O42   68   1.469   1.469   2.822\n    4NOD    H51   69   1.539   1.167   2.892\n    4NOD    O52   70   1.469   1.237   2.822\n    4NOD    H53   71   1.539   1.539   2.519\n    4NOD    O54   72   1.469   1.469   2.590\n    5NOD    Zr9   73   0.000  -0.000   2.954\n    5NOD    O10   74   0.116  -0.116   2.822\n    5NOD    O11   75  -0.116   0.116   2.822\n    5NOD    H16   76  -0.186  -0.186   2.892\n    5NOD    O17   77  -0.116  -0.116   2.822\n    5NOD    H18   78   0.186   0.186   2.892\n    5NOD    O19   79   0.116   0.116   2.822\n    5NOD   Zr36   80  -0.000  -0.248   2.706\n    5NOD   Zr37   81   0.000   0.248   2.706\n    5NOD   Zr38   82  -0.248  -0.000   2.706\n    5NOD   Zr39   83   0.248   0.000   2.706\n    5NOD   Zr40   84  -0.000   0.000   2.457\n    5NOD    O41   85   0.116   0.116   2.590\n    5NOD    O42  ...

# %%
#sub
sub_file = 'Di_SUB.pdb'
sub_class = 'EDGE'
candidate_res_idx_list = [2,3,7,8]
sub_res_newname = 'SUB'
new_mof.defect_replace_linker(sub_file,sub_class,candidate_res_idx_list)
new_mof.write_view_replaced('35.gro')
# Out:
# <div id="3dmolviewer_1731035020701921"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1731035020701921" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_1731035020701921 = null;
# var warn = document.getElementById("3dmolwarning_1731035020701921");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1731035020701921 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1731035020701921"),{backgroundColor:"white"});
# viewer_1731035020701921.zoomTo();
# 	viewer_1731035020701921.addModelsAsFrames("generated by MOF_BUILD\n1776\n    1NOD    Zr9    1   0.000  -0.000   0.248\n    1NOD    O10    2   0.116  -0.116   0.116\n    1NOD    O11    3  -0.116   0.116   0.116\n    1NOD    H16    4  -0.186  -0.186   0.186\n    1NOD    O17    5  -0.116  -0.116   0.116\n    1NOD    H18    6   0.186   0.186   0.186\n    1NOD    O19    7   0.116   0.116   0.116\n    1NOD   Zr36    8  -0.000  -0.248  -0.000\n    1NOD   Zr37    9   0.000   0.248   0.000\n    1NOD   Zr38   10  -0.248  -0.000  -0.000\n    1NOD   Zr39   11   0.248   0.000   0.000\n    1NOD   Zr40   12  -0.000   0.000  -0.248\n    1NOD    O41   13   0.116   0.116  -0.116\n    1NOD    O42   14  -0.116  -0.116  -0.116\n    1NOD    H51   15  -0.186   0.186  -0.186\n    1NOD    O52   16  -0.116   0.116  -0.116\n    1NOD    H53   17   0.186  -0.186  -0.186\n    1NOD    O54   18   0.116  -0.116  -0.116\n    2NOD    Zr9   19   0.000   1.353   1.105\n    2NOD    O10   20   0.116   1.469   1.237\n    2NOD    O11   21  -0.116   1.237   1.237\n    2NOD    H16   22  -0.186   1.539   1.167\n    2NOD    O17   23  -0.116   1.469   1.237\n    2NOD    H18   24   0.186   1.167   1.167\n    2NOD    O19   25   0.116   1.237   1.237\n    2NOD   Zr36   26   0.000   1.601   1.353\n    2NOD   Zr37   27   0.000   1.105   1.353\n    2NOD   Zr38   28  -0.248   1.353   1.353\n    2NOD   Zr39   29   0.248   1.353   1.353\n    2NOD   Zr40   30   0.000   1.353   1.601\n    2NOD    O41   31   0.116   1.237   1.469\n    2NOD    O42   32  -0.116   1.469   1.469\n    2NOD    H51   33  -0.186   1.167   1.539\n    2NOD    O52   34  -0.116   1.237   1.469\n    2NOD    H53   35   0.186   1.539   1.539\n    2NOD    O54   36   0.116   1.469   1.469\n    3NOD    Zr9   37   1.601   2.706   1.353\n    3NOD    O10   38   1.469   2.590   1.469\n    3NOD    O11   39   1.469   2.822   1.237\n    3NOD    H16   40   1.539   2.892   1.539\n    3NOD    O17   41   1.469   2.822   1.469\n    3NOD    H18   42   1.539   2.519   1.167\n    3NOD    O19   43   1.469   2.590   1.237\n    3NOD   Zr36   44   1.353   2.706   1.601\n    3NOD   Zr37   45   1.353   2.706   1.105\n    3NOD   Zr38   46   1.353   2.954   1.353\n    3NOD   Zr39   47   1.353   2.457   1.353\n    3NOD   Zr40   48   1.105   2.706   1.353\n    3NOD    O41   49   1.237   2.590   1.237\n    3NOD    O42   50   1.237   2.822   1.469\n    3NOD    H51   51   1.167   2.892   1.167\n    3NOD    O52   52   1.237   2.822   1.237\n    3NOD    H53   53   1.167   2.519   1.539\n    3NOD    O54   54   1.237   2.590   1.469\n    4NOD    Zr9   55   1.105   1.353   2.706\n    4NOD    O10   56   1.237   1.469   2.590\n    4NOD    O11   57   1.237   1.237   2.822\n    4NOD    H16   58   1.167   1.539   2.892\n    4NOD    O17   59   1.237   1.469   2.822\n    4NOD    H18   60   1.167   1.167   2.519\n    4NOD    O19   61   1.237   1.237   2.590\n    4NOD   Zr36   62   1.353   1.601   2.706\n    4NOD   Zr37   63   1.353   1.105   2.706\n    4NOD   Zr38   64   1.353   1.353   2.954\n    4NOD   Zr39   65   1.353   1.353   2.457\n    4NOD   Zr40   66   1.601   1.353   2.706\n    4NOD    O41   67   1.469   1.237   2.590\n    4NOD    O42   68   1.469   1.469   2.822\n    4NOD    H51   69   1.539   1.167   2.892\n    4NOD    O52   70   1.469   1.237   2.822\n    4NOD    H53   71   1.539   1.539   2.519\n    4NOD    O54   72   1.469   1.469   2.590\n    5NOD    Zr9   73   0.000  -0.000   2.954\n    5NOD    O10   74   0.116  -0.116   2.822\n    5NOD    O11   75  -0.116   0.116   2.822\n    5NOD    H16   76  -0.186  -0.186   2.892\n    5NOD    O17   77  -0.116  -0.116   2.822\n    5NOD    H18   78   0.186   0.186   2.892\n    5NOD    O19   79   0.116   0.116   2.822\n    5NOD   Zr36   80  -0.000  -0.248   2.706\n    5NOD   Zr37   81   0.000   0.248   2.706\n    5NOD   Zr38   82  -0.248  -0.000   2.706\n    5NOD   Zr39   83   0.248   0.000   2.706\n    5NOD   Zr40   84  -0.000   0.000   2.457\n    5NOD    O41   85   0.116   0.116   2.590\n    5NOD    O42  ...
